# %%
using PyPlot
using Statistics

# %%
# Note: Some of the signal processing stuff has been moved into the DSP package in newer Julia versions
# load images with imread (method in both, PyPlot and Images packages)
# I = PyPlot.imread("a1p3.png")
I=PyPlot.imread("a1p3.png")

I=convert(Array{Float64,3}, I)
typeof(I)
# Out:
# Array{Float64,3}

# %%
PyPlot.imshow(I)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.image.AxesImage object at 0x000000002B784518>

# %%
I_gray = 0.2989*I[:,:,1] + 0.5870*I[:,:,2] + 0.1140*I[:,:,3]
# Out:
# 480×480 Array{Float64,2}:
#  0.80288   0.803478  0.804109  0.804508  …  0.577236  0.844723  0.770379
#  0.799489  0.802066  0.802893  0.806204     0.535819  0.694409  0.686937
#  0.806046  0.805621  0.80505   0.801302     0.739922  0.833171  0.824096
#  0.804613  0.810573  0.804206  0.803591     0.83125   0.841404  0.778669
#  0.808456  0.810304  0.810457  0.80641      0.782899  0.694984  0.701134
#  0.801836  0.807125  0.805581  0.806097  …  0.159808  0.194126  0.336298
#  0.801861  0.802484  0.807275  0.807226     0.645553  0.514705  0.386648
#  0.802287  0.802589  0.801725  0.805721     0.738183  0.940845  0.876377
#  0.801775  0.805981  0.798658  0.80251      0.319282  0.629932  0.768828
#  0.805334  0.79922   0.800728  0.803115     0.662845  0.526048  0.667978
#  0.797568  0.803802  0.804897  0.805717  …  0.849024  0.673983  0.768209
#  0.804865  0.800971  0.804508  0.797464     0.817999  0.818417  0.627833
#  0.803625  0.804479  0.801285  0.802975     0.818191  0.824316  0.828905
#  ⋮                                       ⋱
#  0.473432  0.477021  0.475331  0.481756     0.43095   0.42582   0.417762
#  0.479564  0.489992  0.476501  0.479184     0.425598  0.430498  0.423042
#  0.498749  0.503788  0.502225  0.504578  …  0.42341   0.423086  0.429813
#  0.507574  0.502518  0.49459   0.504485     0.432609  0.435657  0.429497
#  0.50291   0.503343  0.507786  0.502584     0.433111  0.421315  0.406143
#  0.503728  0.514759  0.516133  0.500793     0.421608  0.44024   0.439165
#  0.519548  0.511657  0.505508  0.507307     0.405068  0.401716  0.396735
#  0.478997  0.471728  0.463511  0.453366  …  0.411111  0.403239  0.409111
#  0.501994  0.497439  0.493591  0.475553     0.406369  0.41954   0.429715
#  0.498963  0.502929  0.505595  0.50877      0.426172  0.407079  0.407486
#  0.441349  0.447853  0.444429  0.446531     0.436288  0.424426  0.417697
#  0.495415  0.493126  0.495145  0.476053     0.433111  0.43577   0.437398

# %%
PyPlot.axis("off")
PyPlot.imshow(I_gray, "gray")
subt=string("Min: ",string(minimum(I_gray))," Max: ", string(maximum(I_gray))," Mean: ", string(mean(I_gray)))
PyPlot.text(0,500,subt)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject Text(0, 500, 'Min: 0.0 Max: 0.9545444073557854 Mean: 0.4917163009716238')

# %%
# Shift all pixels of i1 to the right by the value of gt
function shift_disparity(i1::Array{Float64,2}, gt::Array{Float64,2})
    @assert size(id) == size(i1)
    
    
    
    shift_img = copy(i1)
    
    for x in 1:size(i1)
        for y in 1:size(i1)
            
        

    
    return id::Array{Float64,2}
end
# Out:
# syntax: incomplete: "function" at none:2 requires end

# %%
for i in [1 2;3 4]
    println(i)
end
# Out:
# 1
# 3
# 2
# 4

# %%
A=[1 2 3;3 4 5]
# Out:
# 2×3 Array{Int64,2}:
#  1  2  3
#  3  4  5

# %%
for i in 1:size(A,2)
    println(i)
end
# Out:
# 1
# 2
# 3
